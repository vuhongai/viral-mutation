# %%
# !git clone https://github.com/brianhie/viral-mutation.git
# %cd viral-mutation

# !wget http://cb.csail.mit.edu/cb/viral-mutation/data.tar.gz
# !tar xvf data.tar.gz
# Out:
# Cloning into 'viral-mutation'...
# remote: Enumerating objects: 1111, done.
# remote: Counting objects: 100% (221/221), done.
# remote: Compressing objects: 100% (154/154), done.
# remote: Total 1111 (delta 133), reused 117 (delta 66), pack-reused 890
# Receiving objects: 100% (1111/1111), 177.41 MiB | 36.27 MiB/s, done.
# Resolving deltas: 100% (741/741), done.
# /content/viral-mutation
# --2022-04-17 16:21:42--  http://cb.csail.mit.edu/cb/viral-mutation/data.tar.gz
# Resolving cb.csail.mit.edu (cb.csail.mit.edu)... 128.30.2.148
# Connecting to cb.csail.mit.edu (cb.csail.mit.edu)|128.30.2.148|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3060938794 (2.9G) [application/x-gzip]
# Saving to: ‘data.tar.gz’
#
# data.tar.gz         100%[===================>]   2.85G  45.1MB/s    in 66s
#
# 2022-04-17 16:22:49 (43.9 MB/s) - ‘data.tar.gz’ saved [3060938794/3060938794]
#
# data/
# data/escape_results.txt
# data/evcouplings/
# ...

# %%
# !pip install anndata scanpy biopython tensorflow-gpu flair python-igraph scipy scikit-learn -q
# Out:
#      |████████████████████████████████| 96 kB 3.9 MB/s
#      |████████████████████████████████| 2.0 MB 19.0 MB/s
#      |████████████████████████████████| 2.3 MB 52.3 MB/s
#      |████████████████████████████████| 497.5 MB 23 kB/s
#      |████████████████████████████████| 401 kB 65.4 MB/s
#      |████████████████████████████████| 88 kB 7.8 MB/s
#      |████████████████████████████████| 11.2 MB 58.6 MB/s
#      |████████████████████████████████| 900 kB 30.7 MB/s
#      |████████████████████████████████| 1.1 MB 55.5 MB/s
#      |████████████████████████████████| 462 kB 60.6 MB/s
#      |████████████████████████████████| 53 kB 1.8 MB/s
#      |████████████████████████████████| 1.2 MB 51.5 MB/s
#      |████████████████████████████████| 19.7 MB 58.9 MB/s
#      |████████████████████████████████| 981 kB 56.4 MB/s
#      |████████████████████████████████| 77 kB 6.7 MB/s
#      |████████████████████████████████| 1.6 MB 47.3 MB/s
#      |████████████████████████████████| 46 kB 4.0 MB/s
# ...

# %%
# !pip install tensorflow==2.4.0

# %%
# %cd viral-mutation/
# Out:
# /content/viral-mutation

# %%
# %%bash
#
# python /content/viral-mutation/bin/cov.py bilstm --checkpoint models/cov.hdf5 --newmut --batch-size 100  \
#     > cov_semantics.log 2>&1
# Out:
# bash: line 3:  1336 Killed                  python /content/viral-mutation/bin/cov.py bilstm --checkpoint models/cov.hdf5 --newmut --batch-size 100 > cov_semantics.log 2>&1
